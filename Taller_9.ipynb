# %% [markdown]
# <a href="https://colab.research.google.com/github/jvera672/cd_202202_juan_vera/blob/main/Taller_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from pandas.core.array_algos.replace import Pattern
# SI EN TU CASA NO QUIERES ESTAR, NO TIENES QUE ESPERAR AL SÁBADO, SI CONMIGO TÚ QUIERES ESTAR NO TIENES QUE ESPERAR, AL SÁBADO, AL SÁBADO
# NO DIGAS QUE SOY ANORMAL POR QUERER SEXO EN LA PLAYA, EN LA PLAYA
# VEN Y DATE SOLO UNA PROBÁA
# PERO MA SI TE GUSTA, NOTE VAYA'

# NO DIGAS QUE SOY ANORMAL POR QUERER SEXO EN LA PLAYA, EN LA PLAYA
# VEN Y DATE SOLO UNA PROBÁA
# PERO MA SI TE GUSTA, NOTE VAYA'

# SIN MIEDO MA, DE LA RUTINA ESCÁPATE
# HOY NOS VAMOS DE PLAYA, EMPACA LA TOALLA
# YO ANDO MAMI, HASTA CON CASETA MONTA'
# READY PA PASARME DE LA RAYA
# Out:
#   File "<ipython-input-1-1124bc56a49b>", line 2
#     SI EN TU CASA NO QUIERES ESTAR, NO TIENES QUE ESPERAR AL SÁBADO, SI CONMIGO TÚ QUIERES ESTAR NO TIENES QUE ESPERAR, AL SÁBADO, AL SÁBADO
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/adiacla/bigdata/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = df.drop('Cabin', axis = 1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df = df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 885      5            382652  29.1250        Q
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [712 rows x 11 columns]

# %%
x = df.iloc[:,[5,6,7]]
y = df.Survived
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.665234
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      709
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                 0.01416
# Time:                        13:44:07   Log-Likelihood:                -473.65
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                  0.001108
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0135      0.003     -5.273      0.000      -0.019      -0.008
# SibSp         -0.1952      0.087     -2.240      0.025      -0.366      -0.024
# Parch          0.2616      0.097      2.703      0.007       0.072       0.451
# ==============================================================================

# %%
import math
print((-0.0135*22-0.1952*0+0.2616*0))
print((1/(1+(math.e)**0.297)))
# Out:
# -0.297
# 0.42629102139255

# %%
df['Sex2'] = np.where(df['Sex'] == 'female', 0, 1)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked  Sex2
# 0        0         A/5 21171   7.2500        S     1
# 1        0          PC 17599  71.2833        C     0
# 2        0  STON/O2. 3101282   7.9250        S     0
# 3        0            113803  53.1000        S     0
# 4        0            373450   8.0500        S     1
# ..     ...               ...      ...      ...   ...
# 885      5            382652  29.1250        Q     0
# 886      0            211536  13.0000        S     1
# 887      0            112053  30.0000        S     0
# 889      0            111369  30.0000        C     1
# 890      0            370376   7.7500        Q     1
#
# [712 rows x 12 columns]

# %%
CONDIMENTOS = [
    (df['Embarked'] == 'C'),
    (df['Embarked'] == 'Q'),
    (df['Embarked'] == 'S')
]

VALORANT = [1, 2, 3]

df['Embarked2'] = np.select(CONDIMENTOS, VALORANT)
df

# conditions = [
#     (df['likes_count'] <= 2),
#     (df['likes_count'] > 2) & (df['likes_count'] <= 9),
#     (df['likes_count'] > 9) & (df['likes_count'] <= 15),
#     (df['likes_count'] > 15)
#     ]

# # create a list of the values we want to assign for each condition
# values = ['tier_4', 'tier_3', 'tier_2', 'tier_1']

# # create a new column and use np.select to assign values to it using our lists as arguments
# df['tier'] = np.select(conditions, values)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked  Sex2  Embarked2
# 0        0         A/5 21171   7.2500        S     1          3
# 1        0          PC 17599  71.2833        C     0          1
# 2        0  STON/O2. 3101282   7.9250        S     0          3
# 3        0            113803  53.1000        S     0          3
# 4        0            373450   8.0500        S     1          3
# ..     ...               ...      ...      ...   ...        ...
# 885      5            382652  29.1250        Q     0          2
# 886      0            211536  13.0000        S     1          3
# 887      0            112053  30.0000        S     0          3
# 889      0            111369  30.0000        C     1          1
# 890      0            370376   7.7500        Q     1          2
#
# [712 rows x 13 columns]

# %% [markdown]
# # Cálculo con sexo

# %%
x = df.iloc[:,[5,6,7,11]]
y = df.Survived
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.548462
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      708
# Method:                           MLE   Df Model:                            3
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.1872
# Time:                        13:44:15   Log-Likelihood:                -390.51
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 9.300e-39
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0208      0.004      5.198      0.000       0.013       0.029
# SibSp         -0.0170      0.102     -0.167      0.867      -0.216       0.182
# Parch          0.1304      0.110      1.188      0.235      -0.085       0.346
# Sex2          -2.0482      0.175    -11.722      0.000      -2.391      -1.706
# ==============================================================================

# %% [markdown]
# #Cálculo con sexo y embarque

# %%
x = df.iloc[:,[5,6,7,11,12]]
y = df.Survived
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.545028
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  712
# Model:                          Logit   Df Residuals:                      707
# Method:                           MLE   Df Model:                            4
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.1923
# Time:                        13:44:16   Log-Likelihood:                -388.06
# converged:                       True   LL-Null:                       -480.45
# Covariance Type:            nonrobust   LLR p-value:                 6.996e-39
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0130      0.005      2.425      0.015       0.002       0.024
# SibSp         -0.0849      0.107     -0.790      0.430      -0.296       0.126
# Parch          0.0769      0.113      0.682      0.495      -0.144       0.298
# Sex2          -2.1962      0.188    -11.687      0.000      -2.564      -1.828
# Embarked2      0.1664      0.076      2.184      0.029       0.017       0.316
# ==============================================================================

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size = 0.20)

# %% [markdown]
# #Sin sexo

# %%
x = train.iloc[:,[5,6,7]]
y = train.Survived
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.665634
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      566
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                 0.01814
# Time:                        13:47:35   Log-Likelihood:                -378.75
# converged:                       True   LL-Null:                       -385.74
# Covariance Type:            nonrobust   LLR p-value:                 0.0009135
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0132      0.003     -4.605      0.000      -0.019      -0.008
# SibSp         -0.2071      0.097     -2.129      0.033      -0.398      -0.016
# Parch          0.2922      0.108      2.694      0.007       0.080       0.505
# ==============================================================================

# %% [markdown]
# #Con sexo

# %%
x = train.iloc[:,[5,6,7,11]]
y = train.Survived
logit_model = sm.Logit(y,x)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.554067
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      565
# Method:                           MLE   Df Model:                            3
# Date:                Sat, 05 Nov 2022   Pseudo R-squ.:                  0.1827
# Time:                        13:48:17   Log-Likelihood:                -315.26
# converged:                       True   LL-Null:                       -385.74
# Covariance Type:            nonrobust   LLR p-value:                 2.347e-30
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0207      0.005      4.593      0.000       0.012       0.030
# SibSp         -0.0596      0.112     -0.530      0.596      -0.280       0.161
# Parch          0.1807      0.122      1.483      0.138      -0.058       0.420
# Sex2          -2.0231      0.197    -10.276      0.000      -2.409      -1.637
# ==============================================================================
