# %% [markdown]
# <a href="https://colab.research.google.com/github/jvera672/cd_202202_juan_vera/blob/main/Taller_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def distancia(x, y):
  return math.sqrt(x**2 + y**2)

# %%
cont = 0
puntosLado = 10000
paso = 1 / (puntosLado - 1)

i = 0
while i <= 1:
  j = 0
  while j <= 1:
    if distancia(i,j) <= 1:
      cont += 1
    j += paso
  i += paso
print("Puntos:", cont)
print("Estimación de pi:", ((cont/puntosLado**2)*4))
# Out:
# Puntos: 78534021
# Estimación de pi: 3.14136084

# %%
import random as rnd
import plotly.express as px

cont = 0
xValues = []
yValues = []
numberOfPoints = 10000
for i in range(numberOfPoints):
  x = rnd.random()
  y = rnd.random()
  if distancia(x,y) <= 1:
    xValues.append(x)
    yValues.append(y)
    cont += 1
print("Puntos:", cont)
print("Estimación de pi:", ((cont/numberOfPoints)*4))
fig = px.scatter(x=xValues, y=yValues, width=400, height=400)
fig.show()
# Out:
# Puntos: 7895
# Estimación de pi: 3.158
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
