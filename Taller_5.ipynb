# %% [markdown]
# <a href="https://colab.research.google.com/github/jvera672/cd_202202_juan_vera/blob/main/Taller_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.stats import pearsonr, zscore

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
#Datos de hoteles
ruta = 'https://raw.githubusercontent.com/rpizarrog/FundamentosMachineLearning/master/datos/melb_data.csv'
df = pd.read_csv(ruta)

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df = df.select_dtypes(exclude=['object'])

# %%
#Buscar nulos
df.isnull().sum()
# Out:
# Rooms               0
# Price               0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# Lattitude           0
# Longtitude          0
# Propertycount       0
# dtype: int64

# %%
#Histograma
df.Price.hist(color='firebrick', bins=30, figsize=(10, 6))

# %%
#Borrado de datos nulos
df = df.dropna()
df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df.plot(x = 'Rooms', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y habitaciones');

# %%
df0 = df.copy()
for columna in df:
  df0 = df0[(np.abs(zscore(df0[columna]))<=3)]

# %%
#Diagrama de distribución Arreglada
fig, ax = plt.subplots(figsize=(10, 6))
df0.plot(x = 'Rooms', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y habitaciones');

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df.plot(x = 'Car', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y carros');

# %%
#Diagrama de distribución Arreglada
fig, ax = plt.subplots(figsize=(10, 6))
df0.plot(x = 'Car', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y carros');

# %%
bestR = 0.0
bestEst2 = None
for column in df0:
  if column != "Price":
    x = df0[column]
    y = df0["Price"]
    x2 = sm.add_constant(x)
    est = sm.OLS(y, x2)
    est2 = est.fit()
    if(est2.rsquared > bestR):
      bestR = est2.rsquared
      bestEst2 = est2
    print(est2.summary())
    sb.set_theme(color_codes=True)
    sb.set_theme(style="ticks")
    ax = sb.regplot(x=column, y="Price", data=df0, marker='+', x_jitter=0.2, y_jitter=0.2)
    ax.set_title('Distribución de Precio y ' + column);
    plt.show(ax)
print("----------------------")
print("----------------------")
print("----------------------")
print("----------------------")
print("Best R-squared: " + str(bestR))
print("----------------------")
print(bestEst2.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     2646.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        13:58:09   Log-Likelihood:                -86605.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6003   BIC:                         1.732e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
df0.iloc[:,[2,4]]
# Out:
#        Distance  Bedroom2
# 1           2.5       2.0
# 2           2.5       3.0
# 4           2.5       3.0
# 6           2.5       4.0
# 7           2.5       2.0
# ...         ...       ...
# 13572      14.5       2.0
# 13573      14.7       4.0
# 13576       6.8       3.0
# 13578       6.8       4.0
# 13579       6.3       4.0
#
# [6660 rows x 2 columns]

# %%
completedList = []
bestR = 0.0
bestEst2 = None
isValidPair = True
#counter = 0
for column1 in df0:
  for column2 in df0:
    if(column1 != column2 and (column1 != "Price") and (column2 != "Price")):
      if(len(completedList) > 0):
        for colPair in completedList:
          if((column1 in colPair) and (column2 in colPair)):
            isValidPair = False
      if(isValidPair):
        #counter += 1
        completedList.append([column1, column2])
        x = df0[[column1, column2]]
        y = df0["Price"]
        x2 = sm.add_constant(x)
        est = sm.OLS(y, x2)
        est2 = est.fit()
        if(est2.rsquared > bestR):
          bestR = est2.rsquared
          bestEst2 = est2
        #print(est2.summary())
        #print(counter)
    isValidPair = True
print("----------------------")
print("Best R-squared: " + str(bestR))
print("----------------------")
print(bestEst2.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# ----------------------
# Best R-squared: 0.5364135126225607
# ----------------------
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     3472.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        13:58:47   Log-Likelihood:                -85393.
# No. Observations:                6005   AIC:                         1.708e+05
# Df Residuals:                    6002   BIC:                         1.708e+05
# Df Model:                           2
# ...
